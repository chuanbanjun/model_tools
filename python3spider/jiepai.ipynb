# %%
import requests
from urllib.parse import urlencode
from requests import codes
import os
from hashlib import md5



def get_page(offset):
    params = {
        'offset': offset,
        'format': 'json',
        'keyword': '节拍',
        'autoload': 'true',
        'count': '20',
        'cur_tab': '1',
        'from': 'search_tab'
    }
    base_url = 'https://www.toutiao.com/search_content/?'
    url = base_url + urlencode(params)
    try:
        resp = requests.get(url)
        if codes.ok == resp.status_code:
            return resp.json()
    except requests.ConnectionError:
        return None


def get_images(json):
    if json.get('data'):
        data = json.get('data')
        for item in data:
            if item.get('cell_type') is not None:
                continue
            title = item.get('title')
            images = item.get('image_list')
            for image in images:
                yield {
                    'image': 'https:' + image.get('url'),
                    'title': title
                }


def save_image(item):
    img_path = 'img' + os.path.sep + item.get('title')
    if not os.path.exists(img_path):
        os.makedirs(img_path)
    try:
        resp = requests.get(item.get('image'))
        if codes.ok == resp.status_code:
            file_path = img_path + os.path.sep + '{file_name}.{file_suffix}'.format(
                file_name=md5(resp.content).hexdigest(),
                file_suffix='jpg')
            if not os.path.exists(file_path):
                with open(file_path, 'wb') as f:
                    f.write(resp.content)
                print('Downloaded image path is %s' % file_path)
            else:
                print('Already Downloaded', file_path)
    except requests.ConnectionError:
        print('Failed to Save Image，item %s' % item)


def main(offset):
    json = get_page(offset)
    for item in get_images(json):
        print(item)
        save_image(item)


if __name__ == '__main__':
    main(20)
# Out:
# {'image': 'https://p3.pstatp.com/list/pgc-image/1535361352575eae5b08b8a', 'title': '最新动感《减肥瘦身操》教学，跟着动感的节拍跳起来吧'}
# Downloaded image path is img\最新动感《减肥瘦身操》教学，跟着动感的节拍跳起来吧\2c3d96d7dee3a16a2f23e6dd539654aa.jpg
# {'image': 'https://p9.pstatp.com/list/pgc-image/1535523643451a9b13f37b0', 'title': '与时光谈场恋爱，调制你的专属夏末红茶“特饮”'}
# Already Downloaded img\与时光谈场恋爱，调制你的专属夏末红茶“特饮”\ff049a261703c9c175a75eacc4fa4ad3.jpg
# {'image': 'https://p3.pstatp.com/list/pgc-image/15353712683782eb35d1383', 'title': '一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……'}
# Downloaded image path is img\一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……\5412868ab1a82f2ef2bc1a9ebc0d75b2.jpg
# {'image': 'https://p1.pstatp.com/list/pgc-image/15353712685175e71b501c1', 'title': '一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……'}
# Downloaded image path is img\一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……\e078bd66da6bb001de44a08570431efc.jpg
# {'image': 'https://p1.pstatp.com/list/pgc-image/15353712684984cda79095b', 'title': '一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……'}
# Downloaded image path is img\一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……\812b0f3cd05c7c7d3ac746324f0dad86.jpg
# {'image': 'https://p3.pstatp.com/list/pgc-image/15353712684507dd279b8a6', 'title': '一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……'}
# Downloaded image path is img\一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……\4243fea8c54789d657e210ceab17c997.jpg
# {'image': 'https://p1.pstatp.com/list/pgc-image/1535371268499be7c3a4319', 'title': '一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……'}
# Downloaded image path is img\一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……\fe4a13a8790bd7ef5dcee4d5fb84d8e2.jpg
# {'image': 'https://p1.pstatp.com/list/pgc-image/1535371268512dd76d88028', 'title': '一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……'}
# Downloaded image path is img\一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……\86564e45e1c25e2f217e0d8f1987d1a1.jpg
# {'image': 'https://p1.pstatp.com/list/pgc-image/1535371268595ca31475ea7', 'title': '一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……'}
# Downloaded image path is img\一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……\e777cf737198c5bb89a46656ec4885ed.jpg
# {'image': 'https://p1.pstatp.com/list/pgc-image/1535371268807b37ebcac94', 'title': '一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……'}
# Downloaded image path is img\一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……\b44d55aaece3b356cad38fb8844e5eff.jpg
# {'image': 'https://p1.pstatp.com/list/pgc-image/1535371268855e083696791', 'title': '一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……'}
# Downloaded image path is img\一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……\5d9f242cf38a47315bbeef66ea592f9c.jpg
# {'image': 'https://p3.pstatp.com/list/pgc-image/1535371268821d48e4c3641', 'title': '一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……'}
# Downloaded image path is img\一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……\7d0d2bddc2b26fb25377cc411a8eb4ae.jpg
# {'image': 'https://p3.pstatp.com/list/pgc-image/153537126877817efca9475', 'title': '一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……'}
# Downloaded image path is img\一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……\7ace9ce8a562e96be210e8cad7cf7bd7.jpg
# {'image': 'https://p3.pstatp.com/list/pgc-image/15353712688209f71230c01', 'title': '一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……'}
# Downloaded image path is img\一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……\8a5828ab1e9000cc9834baef8b4af862.jpg
# {'image': 'https://p3.pstatp.com/list/pgc-image/15353712688855c860f0f7c', 'title': '一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……'}
# Downloaded image path is img\一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……\63198a889d6b7b9f30445ad2b452ec64.jpg
# {'image': 'https://p1.pstatp.com/list/pgc-image/1535371269015a0072f66eb', 'title': '一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……'}
# Downloaded image path is img\一个上海人眼中的克山——清甜泉水、特色美味、悠闲节拍……\b77ae82322b634bc449c449f1222f8cc.jpg
# {'image': 'https://p3.pstatp.com/list/b12b000b370526fec067', 'title': '七彩声控氛围灯随着音乐节拍变换不同的颜色'}
# Downloaded image path is img\七彩声控氛围灯随着音乐节拍变换不同的颜色\f56b4163ff95787265b3da6913a3b93d.jpg
# {'image': 'https://p3.pstatp.com/list/b1730006dee1e67893c9', 'title': '高节拍的食品行业生产线包装线'}
# Downloaded image path is img\高节拍的食品行业生产线包装线\0f7f3d49e60d78afb359f5e5ed063a1f.jpg
# {'image': 'https://p1.pstatp.com/list/b0ac0003c922b50a900b', 'title': '李小璐去事情，萌娃小甜馨急哭又爆金句，哭声还带有节拍感！'}
# Downloaded image path is img\李小璐去事情，萌娃小甜馨急哭又爆金句，哭声还带有节拍感！\51dcba38ca9963d04a7bd88b8d4e32b7.jpg
# {'image': 'https://p3.pstatp.com/list/442900039cf2c2da7442', 'title': '恶搞语音：今天给你们节拍节拍，跟着走'}
# Downloaded image path is img\恶搞语音：今天给你们节拍节拍，跟着走\c8da57599999aec78aaf52b101fcad77.jpg
# {'image': 'https://p1.pstatp.com/list/15a400028203ab7db935', 'title': '强劲节拍，一人一首成名曲'}
# Downloaded image path is img\强劲节拍，一人一首成名曲\aeeec58ca122aa5e8c437ed825a5d7bc.jpg
# {'image': 'https://p1.pstatp.com/list/aee7000593ff5682b0b4', 'title': '这二哈成精了啊，一看就总蹦迪，这节拍踩得太准了！'}
# Downloaded image path is img\这二哈成精了啊，一看就总蹦迪，这节拍踩得太准了！\9213ea4da52ce381604aeee1d44e0688.jpg
# {'image': 'https://p1.pstatp.com/list/102500086bbe03bbd3ec', 'title': '周村旗袍节拍'}
# Downloaded image path is img\周村旗袍节拍\c3eed049c36bda946673859ebbec7013.jpg
# {'image': 'https://p1.pstatp.com/list/102500086bc03d236f91', 'title': '周村旗袍节拍'}
# Downloaded image path is img\周村旗袍节拍\27ef955883f5a8a0ed3a1bd8fe511a72.jpg
# {'image': 'https://p1.pstatp.com/list/106d0003ec3f110088e0', 'title': '周村旗袍节拍'}
# Downloaded image path is img\周村旗袍节拍\3b66b20fb6d97752ec79d6f9467f86b1.jpg
# {'image': 'https://p1.pstatp.com/list/ebc000f1178e3423275', 'title': '精美音乐广场舞 《活力节拍》'}
# Downloaded image path is img\精美音乐广场舞 《活力节拍》\b741c08154b8515ee75cee526f3f6fc5.jpg
# {'image': 'https://p3.pstatp.com/list/26d1000173f91d5932e8', 'title': '《节拍英雄》预告短片'}
# Downloaded image path is img\《节拍英雄》预告短片\75de89b81d0dfcdaf615c58c4568b401.jpg
# {'image': 'https://p9.pstatp.com/list/a25000b2f0c51952a8a', 'title': '潘粤明蒙眼挑战“恶魔节拍”'}
# Downloaded image path is img\潘粤明蒙眼挑战“恶魔节拍”\ad25f8f37ef2c8d8ea28512e70c11396.jpg
# {'image': 'https://p1.pstatp.com/list/7fc0009baee7ff291a3', 'title': '这就是节拍爵士'}
# Downloaded image path is img\这就是节拍爵士\8ed49370df4cc5e8fafdbe943f728a27.jpg
# {'image': 'https://p3.pstatp.com/list/52080012036291e0981d', 'title': '精选广场舞《中国节拍》'}
# Downloaded image path is img\精选广场舞《中国节拍》\afe348ef724bf3e2272e5e688a7a6d4a.jpg

# %%
import requests
from urllib.parse import urlencode
from requests import codes
import os
from hashlib import md5
from multiprocessing.pool import Pool


def get_page(offset):
    params = {
        'offset': offset,
        'format': 'json',
        'keyword': '街拍',
        'autoload': 'true',
        'count': '20',
        'cur_tab': '1',
        'from': 'search_tab'
    }
    base_url = 'https://www.toutiao.com/search_content/?'
    url = base_url + urlencode(params)
    try:
        resp = requests.get(url)
        if codes.ok == resp.status_code:
            return resp.json()
    except requests.ConnectionError:
        return None


def get_images(json):
    if json.get('data'):
        data = json.get('data')
        for item in data:
            if item.get('cell_type') is not None:
                continue
            title = item.get('title')
            images = item.get('image_list')
            for image in images:
                yield {
                    'image': 'https:' + image.get('url'),
                    'title': title
                }


def save_image(item):
    img_path = 'img' + os.path.sep + item.get('title')
    if not os.path.exists(img_path):
        os.makedirs(img_path)
    try:
        resp = requests.get(item.get('image'))
        if codes.ok == resp.status_code:
            file_path = img_path + os.path.sep + '{file_name}.{file_suffix}'.format(
                file_name=md5(resp.content).hexdigest(),
                file_suffix='jpg')
            if not os.path.exists(file_path):
                with open(file_path, 'wb') as f:
                    f.write(resp.content)
                print('Downloaded image path is %s' % file_path)
            else:
                print('Already Downloaded', file_path)
    except requests.ConnectionError:
        print('Failed to Save Image，item %s' % item)


def main(offset):
    json = get_page(offset)
    for item in get_images(json):
        print(item)
        save_image(item)


GROUP_START = 0
GROUP_END = 7

if __name__ == '__main__':
    pool = Pool()
    groups = ([x * 20 for x in range(GROUP_START, GROUP_END + 1)])
    pool.map(main, groups)
    pool.close()
pool.join()
