# %%
import requests
from urllib.parse import urlencode
from pyquery import PyQuery as pq
from pymongo import MongoClient

base_url = 'https://m.weibo.cn/api/container/getIndex?'
headers = {
    'Host': 'm.weibo.cn',
    'Referer': 'https://m.weibo.cn/u/2830678474',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest',
}
client = MongoClient()
db = client['weibo']
collection = db['weibo']
max_page = 10


def get_page(page):
    params = {
        'type': 'uid',
        'value': '2830678474',
        'containerid': '1076032830678474',
        'page': page
    }
    url = base_url + urlencode(params)
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.json(), page
    except requests.ConnectionError as e:
        print('Error', e.args)


def parse_page(json, page: int):
    if json:
        items = json.get('data').get('cards')
        for index, item in enumerate(items):
            if page == 1 and index == 1:
                continue
            else:
                item = item.get('mblog')
                weibo = {}
                weibo['id'] = item.get('id')
                weibo['text'] = pq(item.get('text')).text()
                weibo['attitudes'] = item.get('attitudes_count')
                weibo['comments'] = item.get('comments_count')
                weibo['reposts'] = item.get('reposts_count')
                yield weibo


def save_to_mongo(result):
    if collection.insert(result):
        print('Saved to Mongo')


if __name__ == '__main__':
    for page in range(1, max_page + 1):
        json = get_page(page)
        results = parse_page(*json)
        for result in results:
            print(result)
            save_to_mongo(result)
# Out:
# {'id': '4278160793059549', 'text': '我中了就再抽奖送出去//@NLPJob:问一下右边，要是中奖了怎么处理？//@崔庆才丨静觅: 拉低中奖率//@Fengari:才哥稳的一笔@崔庆才丨静觅', 'attitudes': 0, 'comments': 2, 'reposts': 4}
# Saved to Mongo
# {'id': '4277759108996221', 'text': '拉低中奖率//@Fengari:才哥稳的一笔@崔庆才丨静觅', 'attitudes': 2, 'comments': 5, 'reposts': 30}
# Saved to Mongo
# {'id': '4276611929338402', 'text': '最近压力很大，勿扰，谢谢理解。', 'attitudes': 11, 'comments': 6, 'reposts': 0}
# Saved to Mongo
# {'id': '4275594835262800', 'text': '佛祖保佑，面试顺利！🙏', 'attitudes': 23, 'comments': 14, 'reposts': 1}
# Saved to Mongo
# {'id': '4273274626313421', 'text': '富士拍立得！想要的速来看！', 'attitudes': 1, 'comments': 0, 'reposts': 0}
# Saved to Mongo
# {'id': '4272501490351473', 'text': '哪里可以大批量收集到标题党的新闻啊？', 'attitudes': 2, 'comments': 8, 'reposts': 0}
# Saved to Mongo
# {'id': '4272328815388640', 'text': '有点焦虑，好好调整。', 'attitudes': 7, 'comments': 5, 'reposts': 1}
# Saved to Mongo
# {'id': '4272004045840806', 'text': '求转发！不要去北京五道口的“信服”维修任何设备！这是一家黑店！ 五道口的“信服”你是一家黑店吗？', 'attitudes': 26, 'comments': 31, 'reposts': 100}
# Saved to Mongo
# {'id': '4271927004641793', 'text': '修苹果手机和电脑千万不要去北京五道口购物中心的"信服"，虽然是苹果官方授权店，但绝对是个十足的黑店！', 'attitudes': 8, 'comments': 10, 'reposts': 0}
# Saved to Mongo
# {'id': '4270525645699732', 'text': '哔了狗的一天，手机一个丢了，一个成砖了。', 'attitudes': 1, 'comments': 6, 'reposts': 0}
# Saved to Mongo
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:53: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# {'id': '4269792297417984', 'text': '顺利完成一件人生大事😂😂😂 北京·欧美汇购物中心', 'attitudes': 20, 'comments': 14, 'reposts': 2}
# Saved to Mongo
# {'id': '4269358379826342', 'text': '转发微博', 'attitudes': 1, 'comments': 1, 'reposts': 7}
# Saved to Mongo
# {'id': '4269354386698664', 'text': '', 'attitudes': 6, 'comments': 0, 'reposts': 2}
# Saved to Mongo
# {'id': '4269262711525357', 'text': '6666//@大佬:两台宝马！前所未有！反正转了也不要钱，没准儿就是你的！转我这条加抽666红包！8.10号开，记得关注原po的两个金主！@微博抽奖平台 大佬的秒拍视频', 'attitudes': 0, 'comments': 1, 'reposts': 1}
# Saved to Mongo
# {'id': '4269257619611350', 'text': '抽奖了//@蚁工厂：不让大家看看作者小哥哥吗 @崔庆才丨静觅', 'attitudes': 2, 'comments': 3, 'reposts': 1}
# Saved to Mongo
# {'id': '4268541799176271', 'text': '一文了解 Elasticsearch 及其与 Python 的对接实现一文了解 Elasticsearch 及其与 Python 的对接实现', 'attitudes': 4, 'comments': 2, 'reposts': 6}
# Saved to Mongo
# {'id': '4268519887406018', 'text': '', 'attitudes': 0, 'comments': 0, 'reposts': 2}
# Saved to Mongo
# {'id': '4267861067307512', 'text': '威廉哥的演讲干货满满！另外更重要的是真人比照片更帅！@王威廉 北京·微软亚太研发集团总部 崔庆才丨静觅的秒拍视频', 'attitudes': 7, 'comments': 2, 'reposts': 0}
# Saved to Mongo
# {'id': '4267636429408276', 'text': '', 'attitudes': 2, 'comments': 2, 'reposts': 5}
# Saved to Mongo
# {'id': '4266847937169114', 'text': '转发微博', 'attitudes': 3, 'comments': 0, 'reposts': 1}
# Saved to Mongo
# {'id': '4266502482333204', 'text': '转发微博', 'attitudes': 2, 'comments': 0, 'reposts': 1}
# Saved to Mongo
# {'id': '4265694029573777', 'text': '恭喜@喊我一声就回头 等3名用户获得【《Python3网络爬虫开发实战》】。微博官方唯一抽奖工具@微博抽奖平台 对本次抽奖进行监督，结果公正有效。公证链接：微博抽奖平台', 'attitudes': 7, 'comments': 7, 'reposts': 0}
# Saved to Mongo
# {'id': '4265125835944666', 'text': '', 'attitudes': 0, 'comments': 4, 'reposts': 0}
# Saved to Mongo
# {'id': '4264588570360553', 'text': '赠书了！//@崔庆才丨静觅:送书了！', 'attitudes': 0, 'comments': 0, 'reposts': 1}
# Saved to Mongo
# {'id': '4264588490809473', 'text': '转发微博', 'attitudes': 1, 'comments': 0, 'reposts': 2}
# Saved to Mongo
# {'id': '4264192402347123', 'text': '所以有什么推荐的散热器吗？我这Mac天天发热卡顿//@Mac技术组:我家冰箱里有肉，怕坏//@触动力:周末不在自家冰箱测试跑来公司测试什么！', 'attitudes': 2, 'comments': 1, 'reposts': 23}
# Saved to Mongo
# {'id': '4264183455422301', 'text': '转发微博', 'attitudes': 4, 'comments': 0, 'reposts': 3}
# Saved to Mongo
# {'id': '4263591563518993', 'text': '送书了！', 'attitudes': 3, 'comments': 1, 'reposts': 2}
# Saved to Mongo
# {'id': '4262911058793782', 'text': '赠书了！', 'attitudes': 0, 'comments': 1, 'reposts': 1}
# Saved to Mongo
# {'id': '4262068393249398', 'text': '第三波赠书活动来了！微信公众号"进击的Coder"回复"赠书"即可参与。\n活动详情：《Python3网络爬虫开发实战》第三波赠书活动来了！\n另外转发本微博并艾特三位好友，抽奖额外送三本！开奖时间 2018.7.24。\n谢谢大家支持！', 'attitudes': 39, 'comments': 64, 'reposts': 105}
# Saved to Mongo
# {'id': '4261716877360678', 'text': '头条就是辣鸡', 'attitudes': 7, 'comments': 1, 'reposts': 3}
# Saved to Mongo
# {'id': '4261715984032015', 'text': '今日头条员工被强制离职！匿名爆料，头条员工被强制离职！', 'attitudes': 1, 'comments': 1, 'reposts': 1}
# Saved to Mongo
# {'id': '4260048043672369', 'text': '这份排名是PYPL按照教程搜索量排的 PYPL index PopularitY of Programming Language，但业界应该更信赖Toibe，这上面Java还是稳稳第一 网页链接', 'attitudes': 4, 'comments': 0, 'reposts': 2}
# Saved to Mongo
# {'id': '4259465194240169', 'text': '爬虫速度太慢？来试试用异步协程提速吧！ 爬虫速度太慢？来试试用异步协程提速吧！', 'attitudes': 9, 'comments': 11, 'reposts': 11}
# Saved to Mongo
# {'id': '4257642849012240', 'text': '个人原创，推荐 Mac 上好用的软件你的 Mac 用对了吗？推荐一些 Mac 上比较好用的软件', 'attitudes': 44, 'comments': 7, 'reposts': 104}
# Saved to Mongo
# {'id': '4253432191641911', 'text': '😂可能第二届爬虫大会就是最后一届了', 'attitudes': 4, 'comments': 2, 'reposts': 27}
# Saved to Mongo
# {'id': '4253347181817721', 'text': '看里面说的都是爬虫的基本技术啊@梁斌penny', 'attitudes': 6, 'comments': 4, 'reposts': 4}
# Saved to Mongo
# {'id': '4252355832739651', 'text': '感谢姚老师的赠书@长颈鹿27 ，祝大卖！！！', 'attitudes': 9, 'comments': 2, 'reposts': 0}
# Saved to Mongo
# {'id': '4249894715523590', 'text': '#抽奖# 《Python3网络爬虫开发实战》第二波抽奖赠书活动来了！《Python3网络爬虫开发实战》第二波抽奖赠书活动来了！', 'attitudes': 14, 'comments': 8, 'reposts': 6}
# Saved to Mongo
# {'id': '4249068249747583', 'text': '如何评价杜兰特蝉联 NBA 17-18 赛季总决赛 MVP，而库里第三次无缘 FMVP ？ - 回答作者: 雪百科 网页链接 (想看更多？下载 @知乎 App：知乎 )', 'attitudes': 1, 'comments': 0, 'reposts': 0}
# Saved to Mongo
# {'id': '4248995835004843', 'text': '恭喜我杜！', 'attitudes': 3, 'comments': 0, 'reposts': 0}
# Saved to Mongo
# {'id': '4248024034588869', 'text': '永久封停抖音//@人民日报：【不是一道歉就风轻云淡】犯这种错，抖音让人发抖。犯了改改了再犯，这样的道歉显得廉价，更让人怀疑道歉不过是金蝉脱壳的道具。审核不认真就是给自己挖坑，侮辱英烈已违法。“广告宣传也要讲导向”，绷紧安全弦，始终坚定正确的价值取向，才不会出现致命的方向性错误。', 'attitudes': 1, 'comments': 1, 'reposts': 0}
# Saved to Mongo
# {'id': '4248023603827055', 'text': '赶紧封杀抖音，顺便说一句今日头条吃枣药丸', 'attitudes': 2, 'comments': 0, 'reposts': 0}
# Saved to Mongo
# {'id': '4247992720019604', 'text': '进击的Coder 12种用于Python数据分析的Pandas技巧网页链接', 'attitudes': 3, 'comments': 1, 'reposts': 6}
# Saved to Mongo
# {'id': '4247992582571510', 'text': '分布式爬虫的部署之Gerapy分布式管理分布式爬虫的部署之Gerapy分布式管理', 'attitudes': 8, 'comments': 1, 'reposts': 5}
# Saved to Mongo
# {'id': '4247110796556270', 'text': '分布式爬虫原理之Scrapy分布式实现分布式爬虫原理之Scrapy分布式实现', 'attitudes': 10, 'comments': 0, 'reposts': 5}
# Saved to Mongo
# {'id': '4247109899524121', 'text': '支持崔老师！崔永元真实身份曝光！', 'attitudes': 3, 'comments': 6, 'reposts': 2}
# Saved to Mongo
# {'id': '4246961505081416', 'text': 'PyCon 2018: 利用logging模块轻松地进行Python日志记录 - 崔庆才丨静觅 - 掘金专栏 网页链接', 'attitudes': 6, 'comments': 0, 'reposts': 5}
# Saved to Mongo
# {'id': '4246924519366774', 'text': '重磅事件！崔永元这次捅了天大的篓子，后果可能极其严重！ 三大走向预测', 'attitudes': 5, 'comments': 1, 'reposts': 0}
# Saved to Mongo
# {'id': '4245908151385203', 'text': '', 'attitudes': 0, 'comments': 1, 'reposts': 1}
# Saved to Mongo
# {'id': '4245893702114421', 'text': '#童年照相馆# 感谢掘金', 'attitudes': 15, 'comments': 1, 'reposts': 0}
# Saved to Mongo
# {'id': '4243917992017388', 'text': '', 'attitudes': 20, 'comments': 21, 'reposts': 3}
# Saved to Mongo
# {'id': '4242631959051971', 'text': '我杜盛世美颜', 'attitudes': 1, 'comments': 4, 'reposts': 0}
# Saved to Mongo
# {'id': '4240976157082881', 'text': '抽起来', 'attitudes': 2, 'comments': 6, 'reposts': 4}
# Saved to Mongo
# {'id': '4240743411135429', 'text': '声明你马币', 'attitudes': 11, 'comments': 6, 'reposts': 0}
# Saved to Mongo
# {'id': '4240421980323238', 'text': '恭喜@韩式拌饭危机 等3名用户获得【《Python3网络爬虫开发实战》签名版】。微博官方唯一抽奖工具@微博抽奖平台 对本次抽奖进行监督，结果公正有效。公证链接：微博抽奖平台', 'attitudes': 2, 'comments': 1, 'reposts': 0}
# Saved to Mongo
# {'id': '4240061068961362', 'text': '可这就是一个大屏幕的安卓平板啊，类似RemixOS，代码都撸不了呢。', 'attitudes': 2, 'comments': 12, 'reposts': 1}
# Saved to Mongo
# {'id': '4239689781541350', 'text': '他黄牛逼啊', 'attitudes': 0, 'comments': 0, 'reposts': 1}
# Saved to Mongo
# {'id': '4238202556118448', 'text': '没错，买课程直接送书！！！只有二十个名额！！！网页链接', 'attitudes': 4, 'comments': 3, 'reposts': 0}
# Saved to Mongo
# {'id': '4237856962537339', 'text': '@wonderly321 @AndrewNg吴恩达 @陈独秀 晚//@wonderly321:@王二要找无双 @哆哆哆啦Ssseven_J @简单rainamy 午 //@崔庆才丨静觅:早@蚁工厂 @图灵教育 @wonderly321', 'attitudes': 3, 'comments': 0, 'reposts': 0}
# Saved to Mongo
# {'id': '4237692734665471', 'text': '早@蚁工厂 @图灵教育 @wonderly321', 'attitudes': 5, 'comments': 2, 'reposts': 5}
# Saved to Mongo
# {'id': '4237373032364742', 'text': '老哥太稳了', 'attitudes': 2, 'comments': 1, 'reposts': 12}
# Saved to Mongo
# {'id': '4236412457436086', 'text': '//@不吃胡萝卜的兔子李：他不认识这个字，是怎么打出来的', 'attitudes': 0, 'comments': 2, 'reposts': 0}
# Saved to Mongo
# {'id': '4236047347549333', 'text': '这是你们心心念念的Python网络爬虫秘籍，这文案值一百万！😂这是你们心心念念的Python网络爬虫秘籍', 'attitudes': 14, 'comments': 4, 'reposts': 1}
# Saved to Mongo
# {'id': '4235932129554169', 'text': '@请叫我汪二 @wonderly321 @FindHaoX86', 'attitudes': 0, 'comments': 2, 'reposts': 4}
# Saved to Mongo
# {'id': '4235930993055500', 'text': '【转发抽奖赠书】《Python3网络爬虫开发实战》来了！文末另有抽奖送书及优惠券福利！活动链接: 《Python3网络爬虫开发实战》来了！文末另有抽奖送书及优惠券福利！ 另外转发本微博并艾特三位好友，5.15抽奖再送三本！', 'attitudes': 26, 'comments': 66, 'reposts': 160}
# Saved to Mongo
# {'id': '4235244779504608', 'text': '可以说非常用心了！', 'attitudes': 3, 'comments': 6, 'reposts': 0}
# Saved to Mongo
# {'id': '4233711535096892', 'text': '', 'attitudes': 4, 'comments': 0, 'reposts': 5}
# Saved to Mongo
# {'id': '4233470869992736', 'text': 'Python操作Redis，你要的都在这了！ Python操作Redis，你要的都在这了！', 'attitudes': 5, 'comments': 2, 'reposts': 19}
# Saved to Mongo
# {'id': '4233365407947785', 'text': 'ICLR 2018最佳论文AMSGrad能够取代Adam吗网页链接', 'attitudes': 2, 'comments': 0, 'reposts': 0}
# Saved to Mongo
# {'id': '4232795331191333', 'text': 'Python操作MySQL存储，这些你都会了吗？ Python操作MySQL存储，这些你都会了吗？', 'attitudes': 3, 'comments': 1, 'reposts': 5}
# Saved to Mongo
# {'id': '4232466967536307', 'text': '如何改进梯度下降算法 如何改进梯度下降算法', 'attitudes': 3, 'comments': 0, 'reposts': 2}
# Saved to Mongo
# {'id': '4232022740813057', 'text': 'Python操作MongoDB看这一篇就够了 Python操作MongoDB看这一篇就够了', 'attitudes': 12, 'comments': 1, 'reposts': 12}
# Saved to Mongo
# {'id': '4231378289738604', 'text': '求帮投下70号，谢谢！', 'attitudes': 0, 'comments': 0, 'reposts': 0}
# Saved to Mongo
# {'id': '4231378159274473', 'text': '3个关键点，把你的TensorFlow代码重构为分布式！网页链接', 'attitudes': 1, 'comments': 0, 'reposts': 1}
# Saved to Mongo
# {'id': '4231378067071372', 'text': 'Splash压力过大？来试试负载均衡吧！ Splash压力过大？来试试负载均衡吧！', 'attitudes': 0, 'comments': 0, 'reposts': 0}
# Saved to Mongo
# {'id': '4230984784339627', 'text': '哎呦不错哦', 'attitudes': 7, 'comments': 10, 'reposts': 0}
# Saved to Mongo
# {'id': '4230983370192151', 'text': '大佬们求帮投下70号，其他的几组随便投少的几个就好啦，谢谢！🙏🙏🙏爱读摄影大赛 | 开始投票啦！你的作品入围了吗？', 'attitudes': 2, 'comments': 1, 'reposts': 1}
# Saved to Mongo
# {'id': '4230089727551510', 'text': '', 'attitudes': 1, 'comments': 1, 'reposts': 1}
# Saved to Mongo
# {'id': '4230075035874699', 'text': 'Scrapy对接Docker网页链接', 'attitudes': 3, 'comments': 1, 'reposts': 0}
# Saved to Mongo
# {'id': '4230074364576785', 'text': '正品，有需要的吗？', 'attitudes': 0, 'comments': 3, 'reposts': 0}
# Saved to Mongo
# {'id': '4229064983585072', 'text': '求大家给一号投一下票谢谢！！', 'attitudes': 0, 'comments': 1, 'reposts': 0}
# Saved to Mongo
# {'id': '4229062484907660', 'text': '只会用Selenium爬网页？Appium爬App了解一下只会用Selenium爬网页？Appium爬App了解一下', 'attitudes': 0, 'comments': 3, 'reposts': 8}
# Saved to Mongo
# {'id': '4229006842768161', 'text': '《Python3网络爬虫开发实战》签名版发售了！只在京东、天猫旗舰店销售，这两个旗舰店各有150本的签名本。 链接如下： 人民邮电出版社京东官方旗舰店：网页链接 人民邮电出版社天猫官方旗舰店：宝贝详情 非签名本的店铺推荐如下： 京东自营店：网页链接 当当自营店： ...全文', 'attitudes': 10, 'comments': 20, 'reposts': 9}
# Saved to Mongo
# {'id': '4228882045259874', 'text': '麻烦大家给1号投一票，谢谢！校庆40周年系列活动 | 拍出最美果壳投票开始啦！~ 北京 · 知春路', 'attitudes': 5, 'comments': 1, 'reposts': 1}
# Saved to Mongo
# {'id': '4227717089666111', 'text': '滑动宫格验证码都给碰上了？没事儿，看完此文分分钟拿下！滑动宫格验证码都给碰上了？没事儿，看完此文分分钟拿下！', 'attitudes': 4, 'comments': 0, 'reposts': 2}
# Saved to Mongo
# {'id': '4227643290727223', 'text': '我的《Python3网络爬虫开发实战》等了好久今天终于拿到实体书了😊，印刷质量超赞！首印四千，签了六百，接下来就坐等发货啦🤗 廊坊', 'attitudes': 49, 'comments': 16, 'reposts': 4}
# Saved to Mongo
# {'id': '4227285433350553', 'text': '独立循环神经网络（IndRNN）：打造更长更深的RNN网页链接', 'attitudes': 0, 'comments': 1, 'reposts': 0}
# Saved to Mongo
# {'id': '4226949347438739', 'text': '妈妈再也不用担心爬虫被封号了！手把手教你搭建Cookies池妈妈再也不用担心爬虫被封号了！手把手教你搭建Cookies池', 'attitudes': 6, 'comments': 3, 'reposts': 2}
# Saved to Mongo
# {'id': '4226665733689358', 'text': '设计得超级棒！大赞！', 'attitudes': 8, 'comments': 2, 'reposts': 1}
# Saved to Mongo
# {'id': '4226297821389730', 'text': 'App爬虫神器mitmproxy和mitmdump的使用App爬虫神器mitmproxy和mitmdump的使用', 'attitudes': 4, 'comments': 1, 'reposts': 4}
# Saved to Mongo
# {'id': '4226114446621032', 'text': '#熊猫守护者# 我刚刚加入了“熊猫守护者”，据说会在陕西秦岭种下真实的竹子哦! 你也快来加入我们，一起为萌萌的熊猫种竹子吧！ 熊猫守护者', 'attitudes': 1, 'comments': 0, 'reposts': 0}
# Saved to Mongo
# {'id': '4224885469391821', 'text': '轻松获得海量稳定代理！ADSL拨号代理的搭建轻松获得海量稳定代理！ADSL拨号代理的搭建', 'attitudes': 5, 'comments': 0, 'reposts': 2}
# Saved to Mongo
# {'id': '4224112706612136', 'text': '付费代理的使用付费代理的使用', 'attitudes': 1, 'comments': 0, 'reposts': 2}
# Saved to Mongo
# {'id': '4223799942095803', 'text': '持续集成服务 Travis CI 教程持续集成服务 Travis CI 教程', 'attitudes': 1, 'comments': 0, 'reposts': 0}
# Saved to Mongo
